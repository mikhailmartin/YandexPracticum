# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
# Привет!👋
#
# Меня зовут Андрей Саввин, я стал ревьюером твоего проекта)). Предлагаю перейти на 'ты', но если это неудобно, обязательно скажи об этом!
#
# Пожалуйста не удаляй мои комментарии, они очень пригодятся для нашей работы в случае повторной проверки проекта.
#
# Если у тебя появляются вопросы к моим комментариям, поставь под ними свои комментарии, лучше выделить их цветом или обозначить любым удобным тебе способом, главное чтобы твои комментарии визуально отличались от моих, тогда мы не запутаемся))
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"></a> </h2>
#
# <b>Все отлично!</b> 🏆:
# В случае, если решение на отдельном шаге является полностью правильным.
# </div>
#
#
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"></a> </h2>
#
# <b>Некоторые замечания и рекомендации</b>🔎: В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера<a class="tocSkip"></a> </h2>
#
# <b>На доработку</b>🤔: В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе аналитиком. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓
#
# **🔎В конце блокнота кликабельные ссылки на моменты где нужны правки, для твоего удобства**
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>✍ Комментарий студента</h2>
#
# Здравствуй, Андрей! Надеюсь, в эти непростые времена у тебя всё хорошо.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h2>Комментарий ревьюера</h2>
#
# <b>Некоторые замечания и рекомендации</b>🔎:
#
# Лучше описать всегда в начале цели своими словами, для лучшего понимания задания. Когда описываешь, то легче потом понять взамосвязи шагов и ньюнасы.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>✍ Комментарий студента</h2>
#
# Вставил цели
# </div>

# %% [markdown]
# # Цель исследования
#
# Нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании. Представим, что сейчас декабрь 2016 г., и я планирую кампанию на 2017-й.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats as st

# %% [markdown]
# ## Откройте файл с данными и изучите общую информацию

# %%
data = pd.read_csv('datasets/games.csv')
data.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# <div class="alert alert-warning">
# <h2>Комментарий ревьюера <a class="tocSkip"></a></h2>
#
# <b>1 Некоторые замечания и рекомендации</b>🔎:
#
# Все верно, но можно написать небольшой вывод о структуре данных в таблице.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>✍ Комментарий студента</h2>
#
# Мне не ясно. Что за вывод нужно добавить? В целом же всё отражено в блоке выше.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера 2 <a class="tocSkip"></a></h2>
#
# <b>1 Все отлично!</b> 🏆:
#
# Ну просто как-бы для себя проговорить, и то что видишь выше как-раз изложить в тексте. Просто нужно представить, что эта тетрадка как презентация и ты в текстовом виде рассказываешь презентацию, все шаги связаны логично между собой и последовательны, но много воды тоже не нужно) Но это вообще не критично, просто на будущее. Такой подход и самому будет полезен, часто бывает что к проекту на работе возвращаешься через несколько месяцев и уже забыл сто раз что там было - в такой момент свои же комментарии спасают
# </div>

# %% [markdown]
# ## Подготовьте данные

# %% [markdown]
# ### Замените названия столбцов (приведите к нижнему регистру)

# %%
# data.columns = [i.lower() for i in data.columns]
data.columns = data.columns.str.lower()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера <a class="tocSkip"></a></h2>
#
# <b> 2.1 Все отлично!</b> 🏆:
#
# Все верно. Можно еще использовать конструкцию
#
#     data.columns = data.columns.str.lower()
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>✍ Комментарий студента</h2>
#
# Отличное замечание. Спасибо!
# </div>

# %% [markdown]
# ### Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему

# %%
# data['platform'] = data['platform'].astype('category')  # явные категории
# data['genre'] = data['genre'].astype('category')  # явные категории
# data['rating'] = data['rating'].astype('category')  # явные категории
# data['year_of_release'] = pd.to_datetime(data['year_of_release'], format='%Y')
data['year_of_release'] = data['year_of_release'].astype('Int64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  Int64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: Int64(1), float64(5), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Обработайте пропуски при необходимости

# %%
_ = (
    (data.isna().mean() * 100)
    .to_frame()
    .rename(columns={0: 'space'})
    .query('space > 0')
    .sort_values('space')
    .plot(kind='barh', legend=False, title='Доля пропусков в признаках (что пропуски имеют)')
)

# %% [markdown]
# - `critic_score`: Доля пропусков превышает 50%. Думаю, что заполнять средним или медианным в таком случае некорректно. Скорее всего для многих фильмов вообще нет оценки критиков.
# - `rating`: Доля пропусков превышает 40%. Думаю, что заполнять средним или медианным в таком случае некорректно. Скорее всего данный признак рассчитывается по пользовательским оценкам. В них такая же доля пропусков.
# - `user_score`: Доля пропусков превышает 40%. Думаю, что заполнять средним или медианным в таком случае некорректно. Быть может это новые фильмы или старые, для которых ещё нет пользовательских оценок.
# - `name`: Есть 2 пропуска, но здесь заполнять бессмысленно: имя игры уникально. Не представляю, откуда могли взяться пропуски.
# - `year_of_release`: Сложно представить, как можно заполнить. Если только не идти гуглить ...
# - `genre`: Есть 2 пропуска в столбце. Сложно заполнить без экспертной оценки. Как будто легче удалить эти строчки. Не представляю, откуда могли взяться пропуски.

# %%
data['rating'] = data['rating'].fillna('Unknown')

# %% [markdown]
# `tbd` - To Be Decided. То есть пока без оценки. Мне кажется, что можно заменить на NaN.

# %%
is_tbd = data['user_score'] == 'tbd'
data['is_tbd'] = is_tbd.astype('int')
# data.loc[is_tbd, 'user_score'] = np.NaN
data['user_score'] = data['user_score'].replace('tbd', np.NaN).astype('float')
# data['user_score'] = data['user_score'].astype('float')

# %% [markdown]
# <div class="alert alert-danger">
# <h2>Комментарий ревьюера<a class="tocSkip"></a></h2>
#
# <b> 2.3 На доработку</b>🤔:
#
# Присмотрись ещё к столбцу `year_of_release`, обязателен ли здесь `float`?
#
# <div class="alert alert-warning">
# PS для упрощения конструкции для замены 'tbd' в user score воспользуйся replace
#
#     data['user_score'] = data['user_score'].replace('tbd', np.NaN)
#
# </div>
# <div class="alert alert-success">
# Выводы по пропускам полностю корректы.
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>✍ Комментарий студента</h2>
#
# Я пришёл к выводу, что да, `float` обязателен. Если приводить к формату `datetime`, то добавляется ещё и время вплоть до секунд. А если выбирать из него только год, то из-за пропусков возможно хранить только в `float`. Как то так.
#
# Спасибо, отличное замечание. Исправил код.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <h2>Комментарий ревьюера 2 <a class="tocSkip"></a></h2>
#
# <b> 2.3 На доработку</b>🤔:
#
# Я к тому, что в `year_of_release` `float` можно заменить на `int`)
#
# `int` занимает меньше места это во-первых, а во-вторых год не может быть 2005,5 - так зачем нам тогда `float`? А `datetime`  тут действительно не подходит
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>✍ Комментарий студента</h2>
#
# Не знал, что у Pandas есть возможность ккодировать NaN в целочисленном типе.
# </div>

# %% [markdown]
# ### Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец

# %%
# data['total_sales'] = data['na_sales'] + data['eu_sales'] + data['jp_sales'] + data['other_sales']
data['total_sales'] = data[['na_sales', 'eu_sales', 'jp_sales', 'other_sales']].sum(axis=1)

# %% [markdown]
# <div class="alert alert-warning">
# <h2>Комментарий ревьюера <a class="tocSkip"></a></h2>
#
# <b>2.4 <b>Некоторые замечания и рекомендации</b>🔎:</b>
#
# Правильно.
# Вот еще хорошая конструкция
#
#     data[['na_sales', 'eu_sales','jp_sales', 'other_sales']].sum(axis=1)
#
# Хороша она тем, что быстрее отрабатывает
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>✍ Комментарий студента</h2>
#
# Здорово, спасибо!)
# </div>

# %% [markdown]
# - Было проведено нормирование названий столбцов: все они были приведены к snake_case.
# - Столбец `year_of_release` был приведён к формату `datetime`
# - Пропуски присутствуют в столбцах `critic_score`, `rating`, `user_score`, `name`, `year_of_release`, `genre`. Ни в одном столбце корректно пропуски обработать невозможно.
# - В `genre` пропуски были заменены на `'Unknown'` для более комфортной обработки при визуализации.

# %% [markdown]
# <a id='p2'></a>
# <div class="alert alert-danger">
# <h2>Комментарий ревьюера<a class="tocSkip"></a></h2>
#
# <b> 2 На доработку</b>🤔:
#
# Нужно дорабоатать [замену типов данных](#r1), написать немного пояснений как вывод к пункту, можно посмотреть что можно улучшить в желтых ячейках.
#
# Здесь также обязательно нужна заглушка 'Unknown' для nan значений столбца rating, тк [дальше](#r11) проводится исследование по жанрам и данных об играх без рейтинга не будет на графиках.
#
# В остальном все корректно.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>✍ Комментарий студента</h2>
#
# Заменил тип данных у `year_of_release` на `datetime`.
#
# Вставил выводы к пункту. (как понял)
#
# Добавил заглушку с `Unknown` у `rating`.
# </div>

# %% [markdown]
# <a id='p2'></a>
# <div class="alert alert-danger">
# <h2>Комментарий ревьюера 2 <a class="tocSkip"></a></h2>
#
# <b> 2 На доработку</b>🤔:
#
# Нужно дорабоатать [замену типов данных](#r1).
#
# В остальном все корректно.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>✍ Комментарий студента</h2>
#
# Закодировал год через `Int64`
# </div>

# %% [markdown]
# ## Проведите исследовательский анализ данных

# %% [markdown]
# ### Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?

# %% [markdown]
# "Важны ли данные за все периоды?"
# Смотря для чего... Конечно по графику можно определить, что до 1994 года игр почти не выпускалось.

# %%
_ = data.groupby('year_of_release')['name'].count().plot(kind='bar', figsize=(20, 10))

# %% [markdown]
# <a id='y2'></a>
# <div class="alert alert-warning">
# <h2>Комментарий ревьюера <a class="tocSkip"></a></h2>
#
# <b> 3.1 Некоторые замечания и рекомендации</b>🔎:
#
# Саму фигуру для графика можно изменить в размере, а то не видно подписи на осях - они слились в одно используй параметр figsize внутри plot.
#
#     plot(kind='bar', figsize=(20, 10))
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>✍ Комментарий студента</h2>
#
# Исправил.
# </div>

# %% [markdown]
# ### Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?

# %%
platform_sales = data.groupby('platform')['total_sales'].sum().sort_values(ascending=False)
platform_sales
# Out:
# platform
# PS2     1255.77
# X360     971.42
# PS3      939.65
# Wii      907.51
# DS       806.12
# PS       730.86
# GBA      317.85
# PS4      314.14
# PSP      294.05
# PC       259.52
# 3DS      259.00
# XB       257.74
# GB       255.46
# NES      251.05
# N64      218.68
# SNES     200.04
# GC       198.93
# XOne     159.32
# 2600      96.98
# WiiU      82.19
# PSV       54.07
# SAT       33.59
# GEN       30.77
# DC        15.95
# SCD        1.86
# NG         1.44
# WS         1.42
# TG16       0.16
# 3DO        0.10
# GG         0.04
# PCFX       0.03
# Name: total_sales, dtype: float64

# %% [markdown]
# <div class="alert alert-info">
# <h2>✍ Комментарий студента</h2>
#
# Думаю, у меня вышла не лучшая визуализация. Как можно улучшить?
# </div>

# %%
for platform in platform_sales.index[:5]:
    (
        data.query(f'platform == "{platform}"')
        .groupby('year_of_release')['total_sales'].sum()
        .plot(label=platform, legend=True, figsize=(20, 10))
    )

# %% [markdown]
# Цикл жизни платформы составляет лет 10.

# %% [markdown]
# <div class="alert alert-warning">
# <h2>Комментарий ревьюера <a class="tocSkip"></a></h2>
#
# <b> Некоторые замечания и рекомендации</b>🔎:
#
# Визуализация верная, да). Как улучшить указал [тут](#y2), ну и в конце будет большой [параграф по графике](#g2).
#
# По графику вывод верный
# </div>

# %% [markdown]
# ### Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.

# %% [markdown]
# ### Не учитывайте в работе данные за предыдущие годы.

# %%
sample = data.query('year_of_release > 2013')

# %% [markdown]
# <a id='r2'></a>
# <div class="alert alert-danger">
# <h2>Комментарий ревьюера<a class="tocSkip"></a></h2>
#
# <b>3.4 На доработку</b>🤔:
#
# Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды. В целом резкий спад платформы может произойти буквально за 3 года. Но и слишком короткий период тоже брать не стоит.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>✍ Комментарий студента</h2>
#
# Почитал я в слаке сообщения студентов: стандартное отклонение мнений ревьюеров насчёт выбора интервало велико)))
#
# Было 4, сейчас взял 3.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера <a class="tocSkip"></a></h2>
#
# <b>  3.4 Все отлично!</b> 🏆:
#
# Все верно.
# хмм, интересно что разнятся мнения, не знал)
# </div>

# %% [markdown]
# ### Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.

# %%
# выбираем платформы с наибольшими продажами
_ = sample.groupby('platform')['total_sales'].sum().sort_values().plot(kind='barh', figsize=(12, 6))

# %%
sample = sample[sample['platform'].isin(['PS4', 'PS3', 'XOne', '3DS', 'X360'])]

# %%
_ = sample.groupby(['platform', 'year_of_release'])['total_sales'].sum().unstack('platform').plot(figsize=(12, 6))

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера <a class="tocSkip"></a></h2>
#
# <b>3.5 Все отлично!</b> 🏆:
#
# Все верно.
# </div>

# %% [markdown]
# ### Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.

# %%
_ = sample.boxplot(by='platform', column='total_sales', figsize=(20, 10)).set(ylim=(0, 2))

# %% [markdown]
# По графику видно, что самый "широкий" ящик и с самой большой верхнейй границей у PS4.

# %% [markdown]
# <a id='r3'></a>
# <div class="alert alert-danger">
# <h2>Комментарий ревьюера <a class="tocSkip"></a></h2>
#
# <b>3.4 На доработку</b>🤔:
#
# На графике сложно что-то разглядеть. Во-первых нужно изменить размер фигуры, и во-вторых нужно 'отсечь хвосты' - ограничить график по оси y. В этом поможет следующая конструкция:
#
#     .set(ylim=(0, 2))
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>✍ Комментарий студента</h2>
#
# Исправил
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера 2<a class="tocSkip"></a></h2>
#
# <b>3.4 Все отлично!</b> 🏆:
#
# Все верно.
# </div>

# %% [markdown]
# ### Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.

# %%
_ = pd.plotting.scatter_matrix(
    sample.query('platform == "PS4"')[['total_sales', 'critic_score', 'user_score']],
    figsize=(20, 10),
)

# %%
print(sample.query('platform == "PS4"')['total_sales'].corr(sample['critic_score']))
print(sample.query('platform == "PS4"')['total_sales'].corr(sample['user_score']))
# Out:
# 0.40266141068104083
# -0.04013158947269735

# %% [markdown]
# Есть слабая корреляция между продажами и отзывами критиков.
# Корреляции между отзывами пользователей и продажами почти нет.

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера <a class="tocSkip"></a></h2>
#
# <b>3.7 Все отлично!</b> 🏆:
#
# Все верно, с выводами согласен.
# </div>

# %% [markdown]
# ### Соотнесите выводы с продажами игр на других платформах

# %%
print(sample.query('platform == "PS3"')['total_sales'].corr(sample['critic_score']))
print(sample.query('platform == "PS3"')['total_sales'].corr(sample['user_score']))
# Out:
# 0.44657460493190704
# -0.16676141347662116

# %%
print(sample.query('platform == "X360"')['total_sales'].corr(sample['critic_score']))
print(sample.query('platform == "X360"')['total_sales'].corr(sample['user_score']))
# Out:
# 0.5257228356581521
# -0.138444570945665

# %%
print(sample.query('platform == "XOne"')['total_sales'].corr(sample['critic_score']))
print(sample.query('platform == "XOne"')['total_sales'].corr(sample['user_score']))
# Out:
# 0.42867694370333237
# -0.07038392806475809

# %% [markdown]
# По остальным платформам результаты схожие

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера <a class="tocSkip"></a></h2>
#
# <b>  3.8 Все отлично!</b> 🏆:
#
# Все верно.
# </div>

# %% [markdown]
# ### Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %%
_ = (
    sample
    .groupby('genre')['name']
    .count()
    .sort_values()
    .plot(kind='barh', title='Распределение игр по жанрам', figsize=(12, 6))
)

# %%
_ = (
    sample
    .groupby('genre')['total_sales']
    .sum()
    .sort_values()
    .plot(kind='barh', title='Суммарная доходность жанров', figsize=(12, 6))
)

# %%
_ = sample.boxplot(by='genre', column='total_sales', figsize=(20, 10)).set(ylim=(0, 10))

# %%
_ = (
    sample
    .groupby('genre')['total_sales']
    .median()
    .sort_values()
    .plot(kind='barh', title='Медианная доходность жанров', figsize=(12, 6))
)

# %% [markdown]
# О прибыльности жанров можно судить по графику выше: больше всего игр делается в жанре `action`, он жезарабатывает суммарно больше всего денег.
# Однако же медианные показатели прибыльности игр выше всего у жанра `shooter`.

# %% [markdown]
# <a id='r4'></a>
# <div class="alert alert-danger">
# <h2>Комментарий ревьюера<a class="tocSkip"></a></h2>
#
# <b> 3.9 На доработку</b>🤔:
#
# Общие продажи - плохая метрика для поиска наиболее прибыльного жанра. За высокими показателями общих продаж может скрываться множество мелких игр с низкими продажами. Или 2-3 звезды и куча провалов. Лучше найти жанр, где игры стабильно приносят высокий доход - для этого стоит рассмотреть средние или медианные продажи.
# Обязательно нужно построить еще ящик с усами *как в пункте 3.6* и посмотреть распределения.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>✍ Комментарий студента</h2>
#
# Исправил
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера 2<a class="tocSkip"></a></h2>
#
# <b>  3.9 Все отлично!</b> 🏆:
#
# Все верно.
# </div>

# %% [markdown]
# <a id='p3'></a>
# <div class="alert alert-danger">
# <h2>Комментарий ревьюера<a class="tocSkip"></a></h2>
#
# <b> 3 На доработку</b>🤔:
#
# - обязательно нужно исправить [тут](#r2),[тут](#r3) и [тут](#r4)
# - рекомендации по графикам [тут](#y2)
#
# В остальном все корректно)
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера 2<a class="tocSkip"></a></h2>
#
# <b>  3 Все отлично!</b> 🏆:
#
# Все исправлено верно.
# </div>

# %% [markdown]
# ## Составьте портрет пользователя каждого региона
# Определите для пользователя каждого региона (NA, EU, JP):
# - Самые популярные платформы (топ-5). Опишите различия в долях продаж.
# - Самые популярные жанры (топ-5). Поясните разницу.
# - Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 10))
data.groupby('platform')['na_sales'].sum().sort_values().plot(ax=axes[0], kind='barh')
data.groupby('platform')['eu_sales'].sum().sort_values().plot(ax=axes[1], kind='barh')
data.groupby('platform')['jp_sales'].sum().sort_values().plot(ax=axes[2], kind='barh')
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
data.groupby('platform')['na_sales'].sum().sort_values()[-5:].plot(ax=axes[0], kind='barh')
data.groupby('platform')['eu_sales'].sum().sort_values()[-5:].plot(ax=axes[1], kind='barh')
data.groupby('platform')['jp_sales'].sum().sort_values()[-5:].plot(ax=axes[2], kind='barh')
plt.show()

# %% [markdown]
# Топ-5 популярных платформ в NA:
# 1. X360
# 2. PS2
# 3. Wii
# 4. PS3
# 5. DS
#
# Топ-5 популярных платформ в EU:
# 1. PS2
# 2. PS3
# 3. X360
# 4. Wii
# 5. PS
#
# Топ-5 популярных платформ в JP:
# 1. DS
# 2. PS
# 3. PS2
# 4. SNES
# 5. 3DS

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 10))
data.groupby('genre')['na_sales'].sum().sort_values().plot(ax=axes[0], kind='barh')
data.groupby('genre')['eu_sales'].sum().sort_values().plot(ax=axes[1], kind='barh')
data.groupby('genre')['jp_sales'].sum().sort_values().plot(ax=axes[2], kind='barh')
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
data.groupby('genre')['na_sales'].sum().sort_values()[-5:].plot(ax=axes[0], kind='barh')
data.groupby('genre')['eu_sales'].sum().sort_values()[-5:].plot(ax=axes[1], kind='barh')
data.groupby('genre')['jp_sales'].sum().sort_values()[-5:].plot(ax=axes[2], kind='barh')
plt.show()

# %% [markdown]
# Топ-5 популярных жанров в NA:
# 1. Action
# 2. Sports
# 3. Shooter
# 4. Platform
# 5. Misc
#
# Топ-5 популярных платформ в EU:
# 1. Action
# 2. Sports
# 3. Shooter
# 4. Racing
# 5. Misc
#
# Топ-5 популярных платформ в JP:
# 1. Role-Playing
# 2. Action
# 3. Sports
# 4. Platform
# 5. Misc

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 10))
data.groupby('rating')['na_sales'].sum().sort_values().plot(ax=axes[0], kind='barh')
data.groupby('rating')['eu_sales'].sum().sort_values().plot(ax=axes[1], kind='barh')
data.groupby('rating')['jp_sales'].sum().sort_values().plot(ax=axes[2], kind='barh')
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
data.groupby('rating')['na_sales'].sum().sort_values()[-5:].plot(ax=axes[0], kind='barh')
data.groupby('rating')['eu_sales'].sum().sort_values()[-5:].plot(ax=axes[1], kind='barh')
data.groupby('rating')['jp_sales'].sum().sort_values()[-5:].plot(ax=axes[2], kind='barh')
plt.show()

# %% [markdown]
# В Северной Америке и Европе рейтинги зарабатывают почти в одинаковом соотношении. Только M и T меняются местами.
# А вот в Японии на первом месте с большим отрывом идут игры без рейтинга.

# %% [markdown]
# <a id='r11'></a>
# <div class="alert alert-danger">
# <h2>Комментарий ревьюера<a class="tocSkip"></a></h2>
#
# <b>  На доработку</b>🤔:
#
# После добавления заглушки [тут](#p2) нужно пересмотреть это распределения и сделать вывод о рейтинговой системе Японии.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>✍ Комментарий студента</h2>
#
# Исправил
# </div>

# %% [markdown]
# <a id='p4'></a>
# <div class="alert alert-danger">
# <h2>Комментарий ревьюера<a class="tocSkip"></a></h2>
#
# <b>4 На доработку</b>🤔:
# - Нужно исправить [тут](#r11).
# - По заданию нужно рассмотреть топы 5  и сделеать выводы по распределениям, сейчас на графике показаны все платформы\жанры\рейтинги.
# - Также для удобности сравнения графики можно обьединять с помощью метода subplots.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>✍ Комментарий студента</h2>
#
# - Исправил
# - Считаю, чтобы делать выводы о распределении, необходимо взглянуть на весь топ! (добавил графики только с топ-5)
# - Объединил
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера 2<a class="tocSkip"></a></h2>
#
# <b>  Все отлично!</b> 🏆:
#
# Справился на отлично) Добавлю неочевидный вывод по распределению рейтингов в Японии. Там свой рейтинг оценки игр - поэтому для играм на рынках японии редко присваивается рейтинг по системе, которая есть у нас)
#
# После топ-5 уже теряется какая-либо значимость в нашем случае, но да - твоя логика верная, когда смотришь распределения по корзинам, то лучше посмотреть все, а потом выбрать какой-то топ и рассмотреть его отдельно. Просто так как это обцчение, то задачу упростили и сразу определили интервал (топ 5) чтобы график отражал важную информацию и был читаемым
# </div>

# %% [markdown]
# <a id='g2'></a>
# <div class="alert alert-success">
#
# **Факультатив**
#
# Так же можешь посмотреть на библиотеку seaborn, в ней очень просто строятся графики, они очень хорошо оформлены и их более чем достаточно для задач анализа данных.:
#
#     https://seaborn.pydata.org/index.html
#
# Вот еще одна библиотека, позволяющая делать красивые графики
#
#     https://plotly.com/python/
#
# Она гораздно обширнее и в ней больше возможностей настройки а так же много дополнительных библиотек строится повер  plotly, например dash - https://dash.plotly.com/ - позволит делать интерактивные графики (ползунки, кнопки прямо в графике) и выводить их на отдельный адрес(там с сервером придется повозится), адрес которого можно скидывать кому угодно. Сейчас это врядли тебе понадобится, но на будущее, если изучишь - то большой плюс на работе будет.
#
# Вот также статья хорошая на русском:
#
#     https://habr.com/ru/company/skillfactory/blog/506974/
#
# PS если хочешь быстро строить графики как в seaborn, то есть библиотека cufflinks, в статье о ней написано тоже.
#
# В ней очень просто строятся графики, они очень хорошо оформлены и их более чем достаточно для задач анализа данных.
#
# Ознакомится со всей палитрой графиков и категорий 'когда и что применить' можно тут:
#
#     https://www.python-graph-gallery.com/
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>✍ Комментарий студента</h2>
#
# Спасибо!))
# </div>

# %% [markdown]
# ## Проверьте гипотезы

# %% [markdown]
# ### Средние пользовательские рейтинги платформ Xbox One и PC одинаковые

# %% [markdown]
# H_0: Средние `user_score` для XOne = Средние `user_score` для PC
# H_1: Средние `user_score` для XOne ≠ Средние `user_score` для PC

# %%
sample = data[data['user_score'].notna()]

alpha = 0.05

results = st.ttest_ind(
    sample[sample['platform'] == 'XOne']['user_score'],
    sample[sample['platform'] == 'PC']['user_score'],
    equal_var=False,
)

print(results.pvalue)
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не отвергаем нулевую гипотезу')
# Out:
# 4.935072360183574e-06
# Отвергаем нулевую гипотезу

# %% [markdown]
# То есть рейтинги не одинаковы

# %% [markdown]
# ### Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.

# %% [markdown]
# H_0: Средние `user_score` для Action = Средние `user_score` для Sports
# H_1: Средние `user_score` для Action ≠ Средние `user_score` для Sports

# %%
sample = data[data['user_score'].notna()]

alpha = 0.05

results = st.ttest_ind(
    sample[sample['genre'] == 'Action']['user_score'],
    sample[sample['genre'] == 'Sports']['user_score'],
    equal_var=False,
)

print(results.pvalue)
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не отвергаем нулевую гипотезу')
# Out:
# 0.11483818791498286
# Не отвергаем нулевую гипотезу

# %% [markdown]
# То есть рейтинги одинаковые

# %% [markdown]
# Нулевые гипотезы формировал на равенство. Применял критерий Стьюдента на равенство распределений.

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера 2<a class="tocSkip"></a></h2>
#
# <b>5 Все отлично!</b> 🏆:
#
# Все верно.
# </div>

# %% [markdown]
# <a id='p6'></a>
# <div class="alert alert-danger">
# <h2>Комментарий ревьюера<a class="tocSkip"></a></h2>
#
# <b> Вывод На доработку</b>🤔:
#
# Отстутствует вывод.
# </div>

# %% [markdown]
# # Выводы
#
# 1. У платформ есть цикл жизни. Стоит продавать игры для приставок PS4, XOne, X360, PS3 и 3DS (приоритетность соответствует порядку). Они ещё живы)
# 2. По медианной доходности больше всего зарабатывают игры в жанре "Shooter".
# 3. В зависимости от региона разняться популярности приставки, жанры игр и рейтинги. Топ-5 популярных платформ в NA: X360, PS2, Wii, PS3, DS. Топ-5 популярных платформ в EU: PS2, PS3, X360, Wii, PS. Топ-5 популярных платформ в JP: DS, PS, PS2, SNES, 3DS. Топ-5 популярных жанров в NA: Action, Sports, Shooter, Platform, Misc. Топ-5 популярных платформ в EU: Action, Sports, Shooter, Racing, Misc. Топ-5 популярных платформ в JP: Role-Playing, Action, Sports, Platform, Misc.
# 4. Есть основания утверждать, что средние пользовательские рейтинги платформ Xbox One и PC значимо различаются.
# 5. А вот средние пользовательские рейтинги жанров Action и Sports значимо не различаются.

# %% [markdown]
# <div class="alert alert-info">
# <h2>✍ Комментарий студента</h2>
#
# Добавил
# </div>

# %% [markdown]
# <a id='p6'></a>
# <div class="alert alert-danger">
# <h2>Комментарий ревьюера 2<a class="tocSkip"></a></h2>
#
# <b> Вывод На доработку</b>🤔:
#
# Лучше все же не писать в выводе, что 'лучше взглянуть на графике') Представь, что это презентация, на ней же так не скажешь.
#
# Еще очень смущает формулировка 'не одинаковые', 'не разные' в пунктах 4 и 5, лучше написать, что у нас есть основания утверждать, что средние пользовательские рейтинги платформ Xbox One и PC значимо различаются. В остальном вывод хороший.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>✍ Комментарий студента</h2>
#
# Откорректировал
# На презентации, кстати, именно, что покажешь графики
# Формулировки выбраны исходня из задачи: какой был запрос, такой и ответ
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
# <h2>Общий вывод по проекту <a class="tocSkip"></a></h2>
#
# Cпасибо за твой проект! Было приложено много усилий, чтобы довести его до конца, проделана огромная работа, и это видно невооруженным глазом! Есть несколько важных моментов, которые я отметил и которые можно было бы улучшить, подсказки ты найдешь в моих комментариях.
#
# **Отмечу отдельные положительные моменты проекта🙂**:
#
# * Работа отличная. Ознакомься с рекомендациями, что прокачиваться дальше)
#
# **На что стоит обратить внимание🤓**:
#
# * ~[можно более подробно написать про датасет](#p1)~
# * ~[нужно исправить некоторые пункты предобработки данных](#p2)~
# * ~[нужно исправить некоторые моменты в исследовательском анализе](#p3)~
# * ~[нужны правки в пункте составления портретов пользователей](#p4)~
# * ~[Нужно поправить вывод](#p6)~
# * советы по работе с  [графиками](#g2)
#
# **Успехов в учебе! ОЧень хорошая и осмысленная работа над ошибками)) И сама работа выполнена качественно**
#
# ![gif](https://media1.giphy.com/media/111ebonMs90YLu/giphy.gif?cid=ecf05e47squ85946qbqcaht8169a29teug2h55iz61x9l1k8&rid=giphy.gif&ct=g)
# </div>

# %% [markdown]
# <div class="alert alert-success">
#     <font size="5", color="seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br>
#     <font size="3", color="black">
#     <br>
#     Привет, Михаил :)
#
# Спасибо за работу на проекте
#
# Подведем итоги, мы научились и повторили на проекте каким образом:
#
# + читать тех. задание проекта
# + исследовать неочищенные данные
# + выдвигать гипотезы о пропусках данных и заполнять их значениями
# + принимать решения об удалении некачественных данных
# + находить аномалии в данных и отделять редкие значения
# + соглашаться с наличием пропусков в данных и не забывать об их наличии при фильтрации
# + строить информативные визуализации
# + делить одну выборку на две части
# + находить зависимости и распределения в данных
# + формировать выводы
#
# Навыки отработаны, проект принят
#
# <b>Поздравляю с успешно сданным третьим проектом на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color = "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font>
#     <br>
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br>
#     <font size="3", color = "black">
# <br>
# Привет, Михаил :) Спасибо за все исправления и комментарии, особенно "юморное" настроение :)
#
# Критические ❌ комментарии
#
#
# + проверить корректность заполнения пропусков синтетическими данными
# + __в п. 4.3 добавить расчет коэф. корреляции__
#
# добавил подсказок и бонус
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font>
#     <br>
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color="black"><b>✍ Комментарий студента</b></font>
#
# Вот ты всё ведешь к тому, что не стоит заполнять пропуски в жилой площади.
#
# Окей
#
# А почему тогда это не проблема для кухонной площади? Да и про остальные пропуски тоже ничего не пишешь.
#
# Мне кажется супер странным критерий применимости заполнения пропусков по тому, меняет ли это среднее арифметическое, медиану и пр., потому что это АПРИОРИ.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color="seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
# <br>
# <font size="3", color="black">
# <br>мы с тобой взрослые люди, если я говорю что А это некорректно, значит А1, А2, А3 априори считаются некорректными вещами...
#
# допустим в случае заполнения высоты потолков, это влияет только на один параметр саму колонку, в случае заполнения площадей у нас три взаимосвязанные колонки и для отработки навыка - связывать несколько параметров данных в одно целое - изменяет цвет комментария, он становится красным
#
# сложностей с заполнением пропусков достаточно, и мы будем изучать этот вопрос с разных сторон на протяжении всего курса, т.к. здесь нет простых и эффективных решений, а проблемы с пропусками будут, к сожалению
#
# надеюсь я смог развеять твои сомнения и очертить траекторию развития навыков в борьбе с пропусками
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
# <br>
# <font size="3", color="black">
# <br>Привет, Михаил :) Спасибо, что прислал задание :) Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться).<br>
# <br>
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br>
#     </font>
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев</b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
#     <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br>
#     <font size="3", color="black">
#     <br>
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")
#     <br><br>
#     <a href="https://pyprog.pro/mpl/mpl_short_guide.html">Краткое руководство по Matplotlib</a>
#     На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)</font>
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b></font>
#     <br>
#     <font size="2", color="black">
#     <br>
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br>
#     </font>
# </div>
#
# <div class="alert alert-danger">
#     <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br>
#     <font size="2", color="black">
#     <br>
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br>
#     </font>
# </div>
#
# <div class="alert alert-success">
#     <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br>
#     <font size="3", color="black">
#     <br>
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br>
#     </font>
# </div>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color="black"><b>✍ Комментарий студента</b></font>
#     <br><br>
# <font size="3", color="black">... , вот мой вопрос ...</font>
# </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Название, краткое вступление в работу и главная задача зафиксированы.
#
# Четкий план работ и перечень основных задач позволит коллегам быстрее вникнуть в суть проекта, + будет легче  идти к главной цели проекта

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color="black"><b>✍ Комментарий студента</b></font>
#     <br><br>
# <font size="3", color="black">Хай, Ринат!</font>
# <div>

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />молодец, что делишь блоки загрузки библиотек и датасета, в случае необходимости добавления новых библиотек не придется загружать весь датасет заново и перезапускать проект целиком
# </div>

# %%
data = pd.read_csv('datasets/real_estate_data.csv', sep='\t', parse_dates=['first_day_exposition'])

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0         51.0      8          NaN   False
# 1             NaN          11.0         18.6      1          NaN   False
# 2             NaN           5.0         34.3      4          NaN   False
# 3             NaN          14.0          NaN      9          NaN   False
# 4            3.03          14.0         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
# ...

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  12180.000000
# mean      10.673824     34.457852      5.892358     10.569807      1.150082
# ...

# %%
_ = data.hist(figsize=(15, 20))

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> загрузка и обзор данных проведены корректно
# </div>

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Пропуски
# По выводу ячейки [4] можно понять, что пропуски есть в столбцах `['ceiling_height', 'floors_total', 'living_area', 'is_apartment', 'kitchen_area', 'balcony', 'locality_name', 'airports_nearest', 'cityCenters_nearest', 'parks_around3000', 'parks_nearest', 'ponds_around3000', 'ponds_nearest', 'days_exposition']`. (Всего 14 таких столбцов)

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind= 'barh', figsize=(19,6), rot = -5, legend = False, fontsize = 16)
            .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) ')

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color="black">
#         <b>✍ Комментарий студента</b>
#     </font>
#     <br/>
#     <br/>
#     <font size="3", color="black">
#         Уф, стоит конечно поработать над
#         <a href='https://github.com/google/styleguide/blob/gh-pages/pyguide.md'>стилем кода</a>
#     </font>
# <div>

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    try:
        (
            (df.isna().mean() * 100)
            .to_frame()
            .rename(columns = {0: 'space'})
            .query('space > 0')
            .sort_values(by='space', ascending=True)
            .plot(kind='barh', figsize=(19, 6), rot=-5, legend=False, fontsize=16)
            .set_title('Пример\n', fontsize=22, color='SteelBlue')    
        );    
    except:
        print('пропусков не осталось :)')

# %%
pass_value_barh(data)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Наглядность представления информации одна из важных составляющих работы дата-аналитика или дата-сайентиста

# %% [markdown]
# ##### ceiling_height — высота потолков (м)

# %%
print(f'Доля пропусков {data["ceiling_height"].isna().mean():.2%}')
# Out:
# Доля пропусков 38.80%

# %%
# решил заполнить медианой, так как есть выбивающиеся значения, которые сдвигают среднее
data['ceiling_height'].fillna(data['ceiling_height'].median(), inplace=True)

# %% [markdown]
# *Гипотеза*: Думаю, что многие не знают высоты потолков в своей квартире. Я, например, тоже не помню) К тому же, если выста не экзотична, она не особо интересует покупателей.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />При заполнении медианой необходимо четко отслеживать изменение других статистик: среднее, дисперсию
#
# ... если рассмотреть районность высоты потолков, т.к. в современных районах Питера высота потолков будет ожидаема ниже, чем в исторических, мы увидим, что заполнение подобного объема пропусков медианой или средним значением «размажет» это отличительное свойство объектов недвижимости в центре Питера
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color="black">
#         <b>✍ Комментарий студента</b>
#     </font>
#     <br/>
#     <br/>
#     <font size="3", color="black">
#         Статью я читал. Какое предложение то? Сейчас использовать регрессионую модель?
#     </font>
#     <p>
#         <font size="3", color="black">
#             А что значит "отслеживать"? В случае заполнения срендим/медианой они по-любому изменятся? Что делать дальше?
#         </font>
#      </p>
# <div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />не заполнять, преимуществ от заполнения нет

# %% [markdown]
# ##### floors_total — всего этажей в доме

# %%
print(f'Доля пропусков {data["floors_total"].isna().mean():.2%}')
# Out:
# Доля пропусков 0.36%

# %%
# считаю, здесь нужно заменить пропуски модой
data['floors_total'].fillna(data['floors_total'].mode(), inplace=True)

# %% [markdown]
# *Гипотеза*: Пропусков очень мало. Возможно люди очень редко случайно пропускали данный пункт по какой-либо причине.

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />После заполнения синтетическими данными, стоит провести проверку на корректность значений по условию (этажность дома не м.б. ниже этажности квартиры)
#
#     ['floors_total'] < ['floor']

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color="black">
#         <b>✍ Комментарий студента</b>
#     </font>
#     <br/>
#     <br/>
#     <font size="3", color="black">
#         Отличное замечание!
#     </font>
# <div>

# %%
def chek_floors(row):
    result = row['floors_total']
    if result < row['floor']:
        result = row['floor']
    
    return result

# %%
data['floors_total'] = data.apply(chek_floors, axis=1)

# %% [markdown]
# ###### check r.2.1

# %%
# check

data[data['floors_total'] < data['floor']]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []

# %% [markdown]
# ##### living_area — жилая площадь в квадратных метрах (м²)

# %%
print(f'Доля пропусков {data["living_area"].isna().mean():.2%}')
# Out:
# Доля пропусков 8.03%

# %%
# решил заполнить медианой, так как есть выбивающиеся значения, которые сдвигают среднее
# data['living_area'].fillna(data['living_area'].median(), inplace=True)

# %% [markdown]
# Не могу предположить, по какой причине здесь появились пропуски.

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Размер жилой площади помнят чуть больше людей чем высоту потолков, но не все :)
#
# После заполнения синтетическими данными столбцов, стоит провести проверку на корректность значений всех наших площадей, т.к. есть (коридоры, сан.узлы, балконы)
#
#         total_area*0.9 <= (living_area + kitchen_area)
#
# если алгоритм приводит к появлению аномалий, стоит подумать над его содержимым

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color="black">
#         <b>✍ Комментарий студента</b>
#     </font>
#     <br/>
#     <br/>
#     <font size="3", color="black">
#         Отличное замечание!
#     </font>
# <div>

# %%
# def chek_living_area(row):
#     result = row['living_area']
#     if row['total_area'] * 0.9 <= result + row['kitchen_area']:
#         result = row['total_area'] * 0.9 - row['kitchen_area']
    
#     return result

# %%
# data['living_area'] = data.apply(chek_living_area, axis=1)

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />ф-я осталась недописанной

# %% [markdown]
# ##### is_apartment — апартаменты (булев тип)

# %%
print(f'Доля пропусков {data["is_apartment"].isna().mean():.2%}')
# Out:
# Доля пропусков 88.29%

# %% [markdown]
# Оставил пропуски, так как их доля очень велика.
# *Гипотеза*: может это новая фича, которая появилась не так давно.

# %% [markdown]
# ##### kitchen_area — площадь кухни в квадратных метрах (м²)

# %%
print(f'Доля пропусков {data["kitchen_area"].isna().mean():.2%}')
# Out:
# Доля пропусков 9.61%

# %%
# решил заполнить медианой, так как есть выбивающиеся значения, которые сдвигают среднее
data['kitchen_area'].fillna(data['kitchen_area'].median(), inplace=True)

# %% [markdown]
# Не могу предположить, по какой причине здесь появились пропуски.
# Вряд ли бывают квартиры без кухни. При чём, что их доля порядка 1/10.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> часть из них может быть студиями

# %% [markdown]
# ##### balcony — число балконов

# %%
print(f'Доля пропусков {data["balcony"].isna().mean():.2%}')
# Out:
# Доля пропусков 48.61%

# %%
# пример из задания
data['kitchen_area'].fillna(0, inplace=True)

# %% [markdown]
# ##### locality_name — название населённого пункта

# %%
print(f'Доля пропусков {data["locality_name"].isna().mean():.2%}')
# Out:
# Доля пропусков 0.21%

# %% [markdown]
# <font color='red'>Стоило их заполнить модой?</font>
# Не могу предположить, по какой причине здесь появились пропуски.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />нет, это категориальные данные, заполнять модой мы не можем, можно по геоточкам попытаться определить название населенного пункта, но и там данных недостаточно

# %% [markdown]
# ##### airports_nearest — расстояние до ближайшего аэропорта в метрах (м)

# %%
print(f'Доля пропусков {data["airports_nearest"].isna().mean():.2%}')
# Out:
# Доля пропусков 23.38%

# %%
# решил заполнить СРЕДНИМ, так как хвост распределения не большой
data['kitchen_area'].fillna(data['kitchen_area'].mean(), inplace=True)

# %% [markdown]
# *Гипотеза*: Я бы предположил, что если стоит пропуск, значит нет ближайшего аэропорта в некоторой ограниченной зоне.  Но их что-то слишком много ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />может быть этот пул параметров предназначен только для Питера, парки, водоемы, аэропорт ...

# %% [markdown]
# ##### cityCenters_nearest — расстояние до центра города (м)

# %%
print(f'Доля пропусков {data["cityCenters_nearest"].isna().mean():.2%}')
# Out:
# Доля пропусков 23.29%

# %% [markdown]
# *Гипотеза*: Здесь могут быть объекты не расположенные в городе. Но тоже их как-то многовато.
# Думаю, что эт оважные пропуски. Не стал их заполнять.

# %% [markdown]
# ##### parks_around3000 — число парков в радиусе 3 км

# %%
print(f'Доля пропусков {data["parks_around3000"].isna().mean():.2%}')
# Out:
# Доля пропусков 23.28%

# %% [markdown]
# *Гипотеза*: Возможно так же как с балконами: если рядом парка нет, люди ничего и не поставили.

# %%
data['parks_around3000'].fillna(0, inplace=True)

# %% [markdown]
# ##### parks_nearest — расстояние до ближайшего парка (м)

# %%
print(f'Доля пропусков {data["parks_nearest"].isna().mean():.2%}')
# Out:
# Доля пропусков 65.91%

# %% [markdown]
# Доля пропусков слишком велика, чтобы заполнять чем-то.
# *Гипотеза*: Люди не знают расстояние до ближайшего парка.

# %% [markdown]
# ##### ponds_around3000 — число водоёмов в радиусе 3 км

# %%
print(f'Доля пропусков {data["ponds_around3000"].isna().mean():.2%}')
# Out:
# Доля пропусков 23.28%

# %% [markdown]
# Гипотеза: Возможно так же как с балконами: если рядом водоёма нет, люди ничего и не поставили.

# %%
data['ponds_around3000'].fillna(0, inplace=True)

# %% [markdown]
# ##### ponds_nearest — расстояние до ближайшего водоёма (м)

# %%
print(f'Доля пропусков {data["ponds_nearest"].isna().mean():.2%}')
# Out:
# Доля пропусков 61.56%

# %% [markdown]
# Доля пропусков слишком велика, чтобы заполнять чем-то.
# *Гипотеза*: Люди не знают расстояние до ближайшего водоёма.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# описание проекта часто выручает дата-аналитика и дата сайентиста
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### days_exposition — сколько дней было размещено объявление (от публикации до снятия)

# %%
print(f'Доля пропусков {data["days_exposition"].isna().mean():.2%}')
# Out:
# Доля пропусков 13.42%

# %%
# data['days_exposition'].fillna(data['days_exposition'].median(), inplace=True)

# %% [markdown]
# *Гипотеза*: это новые объявления, которые размещены меньше суток.

# %% [markdown]
# <div class="alert alert-dang
#             er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> пропуски в ['days_exposition'] говорят нам, что квартиры еще не проданы..., неверно терять столь важный признак, → оставляем пропуски

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для проверки предположения можно сопоставить дату публикации и пропуск
#
# Описание данных
# + airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# + balcony — число балконов
# + ceiling_height — высота потолков (м)
# + cityCenters_nearest — расстояние до центра города (м)
# + __days_exposition — сколько дней было размещено объявление (от публикации до снятия)__
# + __first_day_exposition — дата публикации__

# %% [markdown]
# **Заметки**: Ещё можно заметить сопоставимую долю пропусков у фич `airports_nearest`, `cityCenters_nearest`, `parks_around3000` и `ponds_around3000` в 23.3%; а у `parks_nearest` и `ponds_nearest` в 63%.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />верное замечание

# %% [markdown]
# #### Типы данных

# %% [markdown]
# - Даты я ещё на этапе чтения файла привёл к `datetime`.
# - Можно оптимизировать выделенную память, понизив размерность типов численных данных.

# %%
for i in ['integer', 'float']:
    for column in data.select_dtypes(i):
        data[column] = pd.to_numeric(data[column], downcast=i)

# %% [markdown]
# #### Устранения неявных дубликатов (нормализация)

# %%
for i in data.loc[data['locality_name'].notna(), 'locality_name'].unique():
    data['locality_name'].replace({i: i.replace('поселок', 'посёлок')}, inplace=True)
    data['locality_name'].replace({i: i.replace('городской посёлок', 'посёлок городского типа')}, inplace=True)

# %%
# check
data['locality_name'].nunique()
# Out:
# 325

# %% [markdown]
# #### Устранение редких и выбивающихся значений

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int8
#  1   last_price            23699 non-null  float32
#  2   total_area            23699 non-null  float32
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int8
#  5   ceiling_height        23699 non-null  float32
#  6   floors_total          23613 non-null  float32
#  7   living_area           21796 non-null  float32
#  8   floor                 23699 non-null  int8
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          23699 non-null  float32
#  13  balcony               12180 non-null  float32
# ...

# %%
# data['total_images']  # нужно ли чистить этот столбец? как? почему?
data = data.query('last_price <= 2e7')  # порог подбирал так, чтобы не очень много отсечь. этот убирает ~3%
data = data.query('total_area <= 150')  # порог подбирал так, чтобы не очень много отсечь. этот убирает ~3%
data.loc[data['ceiling_height'] >= 20, 'ceiling_height'] /= 10
data = data.query('2 <= ceiling_height <= 4')
data = data.query('rooms <= 6')
# data['floors_total']  # нужно ли чистить этот столбец? как? почему?
data = data.query('7 <= living_area <= 150')  # порог подбирал так, чтобы не очень много отсечь. этот убирает ~1.5%
data = data.query('5 <= kitchen_area <= 35')  # порог подбирал так, чтобы не очень много отсечь. этот убирает ~1.5%
# порог подбирал так, чтобы не очень много отсечь. этот убирает ~1%
data = data.query('airports_nearest <= 60_000 or airports_nearest.isna()')
# порог подбирал так, чтобы не очень много отсечь. этот убирает ~1%
data = data.query('cityCenters_nearest <= 40_000 or cityCenters_nearest.isna()')
# data['parks_nearest']  # нужно ли чистить этот столбец? как? почему?
# порог подбирал так, чтобы не очень много отсечь. этот убирает ~1%
data = data.query('days_exposition <= 1000 or days_exposition.isna()')

# %% [markdown]
# А в чем цель удалять строчки с редкими, но реалистичными значениями?
# Понятно, например, что высота потолков в 20м - это ошибка, а вот квартира площадью 900м2 бывает!
#
# Эта часть просто невероятно утомила!
# 1. Я не понимаю, зачем она вообще нужна!
# 2. По каким критериям нужно удалять выбивающиеся значения?
# 3. В каких столбцах?

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __проверим какие аномалии остались__ таблица ниже

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир
# сырые данные

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area', 'floor',
       'floors_total']]
    .apply (['count', 'min', 'max'])   
    .style.format("{:,.2f}")
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ae7c3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae7c3_level0_col0" class="col_heading level0 col0" >rooms</th>
#       <th id="T_ae7c3_level0_col1" class="col_heading level0 col1" >total_area</th>
#       <th id="T_ae7c3_level0_col2" class="col_heading level0 col2" >ceiling_height</th>
#       <th id="T_ae7c3_level0_col3" class="col_heading level0 col3" >days_exposition</th>
#       <th id="T_ae7c3_level0_col4" class="col_heading level0 col4" >last_price</th>
#       <th id="T_ae7c3_level0_col5" class="col_heading level0 col5" >living_area</th>
#       <th id="T_ae7c3_level0_col6" class="col_heading level0 col6" >kitchen_area</th>
#       <th id="T_ae7c3_level0_col7" class="col_heading level0 col7" >floor</th>
#       <th id="T_ae7c3_level0_col8" class="col_heading level0 col8" >floors_total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Ювелирная работа по избавлению от редкостей и аномалий, молодец
#
# стоит удалить аномально минимальную жил.площадь и кухни

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для выпонения пункта 2.4. существует два подхода
#
# Можно механически бороться с выбросами, ...
#
# основная проблема такого подхода — не учитывается неоднородность нашей выборки: у нас здесь и малые поселки и вторая столица страны, и исторический фонд и массовая застройка, и однушки и довольно большое кол-во многокомнатных квартир, или наоборот одна две квартиры с кол-ом комнат больше 7-ми ...
#
#
#
# если бы у нас в таблице были бы только однокомнатные квартиры из определенного района массовой застройки, тогда да, мы бы боролись с выбросами традиционными способами, при нашем многообразии населенных пунктов, многокомнатности такие подходы не работают... т.е. они работают, но это усложнит наш проект — придется разбить и объединить записи нашей таблицы по нескольким параметрам (кол-во комнат, район, и т.д.), а затем только выполнять все остальные пункты на каждой отдельной выборке
#
# Остается другой подход — убираем редкие значения и следим за количеством потерь...
#
# Для выборки из 23-х тысяч значений, 4 записи со стоимостью квадратного метра выше 10 млн. руб., довольно редкое явление
#
# Хороший пример, высота потолков, которую мы отрезаем по нижней и верхней планке, это скорее аномальные записи, посмотрим на другой аспект — на редкости: кол-во комнат
#
# __т.е. мы не говорим о том, что квартир с кол-ом комнат выше 7 не бывает, мы говорим, что для нашего исследования это редкие выбивающиеся из общей картины уникальные объекты, по которым необходимо проводить отдельную работу ..__
#
# подобным образом рассматриваем и остальные параметры
#
# наши ~~помошники~~ помощники
#
# 1. гистограммы, с хорошим масштабом
# 2. метод describe() или облегченная версия, пример выше
# 3. метод value_counts()
#
# плюс жизненный опыт

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color="black">
#         <b>✍ Комментарий студента</b>
#     </font>
#     <br/>
#     <br/>
#     <font size="3", color="black">
#         помоЩник
#     </font>
# <div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />исправлено :)

# %%
# check
# пример на сырых данных
try:
    df_check = pd.read_csv('real_estate_data.csv', sep='\t') 
except:
    df_check = pd.read_csv('datasets/real_estate_data.csv', sep='\t')

# %%
# check
df_check.total_area.hist(bins = 150, figsize = (15, 3))
# Out:
# <AxesSubplot: >

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />т.е. все квартиры более двухсот квадратных метров можно считать редкостями
#
# особенно это заметно на втором графике, где мы подробно рассматриваем промежуток от 180 кв. метров до 500

# %%
# check
df_check.total_area.hist(bins=150, figsize=(15, 3), range=(180, 500))

# %%
# check

# Значения параметров объектов недвижимости на разных квантилях

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  
        'kitchen_area', 'floor',   'floors_total']]
    .quantile([0.01, .5, .90, .9976])  
    .style.format("{:,.2f}")
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ad214">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad214_level0_col0" class="col_heading level0 col0" >rooms</th>
#       <th id="T_ad214_level0_col1" class="col_heading level0 col1" >total_area</th>
#       <th id="T_ad214_level0_col2" class="col_heading level0 col2" >ceiling_height</th>
#       <th id="T_ad214_level0_col3" class="col_heading level0 col3" >days_exposition</th>
#       <th id="T_ad214_level0_col4" class="col_heading level0 col4" >last_price</th>
#       <th id="T_ad214_level0_col5" class="col_heading level0 col5" >living_area</th>
#       <th id="T_ad214_level0_col6" class="col_heading level0 col6" >kitchen_area</th>
#       <th id="T_ad214_level0_col7" class="col_heading level0 col7" >floor</th>
#       <th id="T_ad214_level0_col8" class="col_heading level0 col8" >floors_total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Квантили что это такое
#
# https://fin-accounting.ru/cfa/l1/quantitative/cfa-quartiles-quintiles-deciles-percentiles?ysclid=l7gy2kky4i156375632
#
# стоит использовать перед очисткой и следить за минимальными значениями

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %%
def floor_type(row):
    if row['floor'] <= 0:
        result = 'формат неизвестный'
    elif row['floor'] == 1:
        result = 'первый'
    elif row['floor'] == row['floors_total']:
        result = 'последний'
    else:
        result = 'другой'
        
    return result

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Функция хорошая, стоит учесть крайние условия: нулевые и отрицательные значения

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color="black">
#         <b>✍ Комментарий студента</b>
#     </font>
#     <br/>
#     <br/>
#     <font size="3", color="black">
#         Что стоит вернуть в случае x <= 0?<br>
#     </font>
# <div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />исключение или категорию "формат неизвестный"

# %%
data['meter_price'] = data['last_price'] / data['total_area']
data['weekday'] = data['first_day_exposition'].dt.weekday
data['month'] = data['first_day_exposition'].dt.month
data['year'] = data['first_day_exposition'].dt.year
data['floor_type'] = data.apply(floor_type, axis=1)
data['cityCenters_km'] = round(data['cityCenters_nearest'] / 1000)

# %% [markdown]
# <div class="alert alert-da
#             nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />стоит откорректировать,
#
# стоимость кв. метра рассчитывается от общей площади
#
#         data['meter_price'] = data['last_price'] / data['living_area']

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color="black">
#         <b>✍ Комментарий студента</b>
#     </font>
#     <br/>
#     <br/>
#     <font size="3", color="black">
#         Да, действительно!
#     </font>
# <div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> остальные данные добавлены корректно, молодец

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# #### Изучаем параметры объектов

# %%
ax = data['total_area'].hist(bins=50, figsize=(10, 7))
ax.set_title('Распределение общих площадей')
ax.set_xlabel('общая площадь')
ax.set_ylabel('частота')
plt.show()

# %% [markdown]
# Распределение Пуассона

# %%
ax = data['living_area'].hist(bins=50, figsize=(10, 7))
ax.set_title('Распределение жилих площадей')
ax.set_xlabel('жилая площадь')
ax.set_ylabel('частота')
plt.show()

# %% [markdown]
# Распределение Пуассона с 2 ярко выраженными пиками. Пик около 30 - заполнение пропусков медианой. А вот пик 18-19 интересен.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Хорошие графики, можно добавить кол-во корзин к параметрам гистограммы
#
# Подписи осей на графиках и название добавят ясности и читабельности.
# Это важные элементы любой визуализации. Как добавить подписи и названия, смотри [здесь](https://pyprog.pro/mpl/mpl_axis_signatures.html) и [там](https://pyprog.pro/mpl/mpl_title.html), и [тут](https://proproprogs.ru/modules/matplotlib-razmeshchaem-standartnye-tekstovye-elementy-na-grafike?ysclid=l6agtioc6f299002507) :)

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color="black">
#         <b>✍ Комментарий студента</b>
#     </font>
#     <br/>
#     <br/>
#     <font size="3", color="black">
#         "тут" улетело
#     </font>
# <div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />выделено отдельно специально, материал доступнее, мое субъективное мнение

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color="black">
#         <b>✍ Комментарий студента</b>
#     </font>
#     <br/>
#     <br/>
#     <font size="3", color="black">
#         Думаю, что ты выбрал не лучший приём для выделения. Может стоит в верхний регистр перевести или поменять цвет гиперссылки?
#     </font>
# <div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />принято :)

# %%
ax = data['kitchen_area'].hist(bins=50, figsize=(10, 7))
ax.set_title('Распределение площадей кухонь')
ax.set_xlabel('общая кухни')
ax.set_ylabel('частота')
plt.show()

# %% [markdown]
# Распределение Пуассона с ярким пиком, обоснованный заполнением медианой.

# %%
ax = data['last_price'].hist(bins=50, figsize=(10, 7))
ax.set_title('Распределение цен')
ax.set_xlabel('цена')
ax.set_ylabel('частота')
plt.show()

# %% [markdown]
# Распределение Пуассона

# %%
ax = data['rooms'].hist(bins=7, figsize=(10, 7))
ax.set_title('Распределение количества комнат')
ax.set_xlabel('количество комнат')
ax.set_ylabel('частота')
plt.show()

# %% [markdown]
# Странно, что кто-то указал 0 комнат. В остальном всё норм.

# %%
ax = data['ceiling_height'].hist(figsize=(10, 7))
ax.set_title('Распределение высоты потолков')
ax.set_xlabel('высота потолков')
ax.set_ylabel('частота')
plt.show()

# %% [markdown]
# Здесь тоже всё ожидаемо

# %%
ax = data['floor'].hist(bins=33, figsize=(10, 7))
ax.set_title('Распределение этажей')
ax.set_xlabel('этаж')
ax.set_ylabel('частота')
plt.show()

# %% [markdown]
# Сильно много сдаётся первых этажей.

# %% [markdown]
# <div class="alert alert-da
#             nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# стоит изменить параметры отображения гистограммы, сейчас может показаться, что
#
#         Сильно много сдаётся первых этажей.

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color="black">
#         <b>✍ Комментарий студента</b>
#     </font>
#     <br/>
#     <br/>
#     <font size="3", color="black">
#         Много продаётся квартир на первых пяти этажах.
#     </font>
# <div>

# %%
ax = data['floor_type'].hist(figsize=(10, 7))
ax.set_title('Распределение типов этажей')
ax.set_xlabel('тип этажа')
ax.set_ylabel('частота')
plt.show()

# %% [markdown]
# Оказывается и последних тоже.

# %% [markdown]
# <div class="alert alert-da
#             nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# стоит подправить вывод
#
#         Оказывается и последних тоже.

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color="black">
#         <b>✍ Комментарий студента</b>
#     </font>
#     <br/>
#     <br/>
#     <font size="3", color="black">
#         Здесь как ни крути квартир на первых и последних этажах продаётся много! (имхо)
#     </font>
# <div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />слово оказывается :)

# %%
ax = data['floors_total'].hist(figsize=(10, 7))
ax.set_title('Распределение этажности домов')
ax.set_xlabel('этажность дома')
ax.set_ylabel('частота')
plt.show()

# %%
ax = data['cityCenters_nearest'].hist(bins=50, figsize=(10, 7))
ax.set_title('Распределение расстояний до центра')
ax.set_xlabel('расстояние до центра')
ax.set_ylabel('частота')
plt.show()

# %% [markdown]
# Интересное распределение. Есть 3 пика: около 5км, 15км и 31км.

# %%
ax = data['airports_nearest'].hist(bins=50, figsize=(10, 7))
ax.set_title('Распределение расстояний до ближайшего аэропорта')
ax.set_xlabel('расстояние до ближайшего аэропорта')
ax.set_ylabel('частота')
plt.show()

# %% [markdown]
# Рядом с аэропортом никто не живёт. В остальном всё норм.

# %%
ax = data['parks_nearest'].hist(bins=50, figsize=(10, 7))
ax.set_title('Распределение расстояний до ближайшего парка')
ax.set_xlabel('расстояние до ближайшего парка')
ax.set_ylabel('частота')
plt.show()

# %% [markdown]
# Распределение Пуассона

# %%
ax = data['weekday'].hist(bins=7, figsize=(10, 7))
ax.set_title('Распределение по дня недели')
ax.set_xlabel('день недели')
ax.set_ylabel('частота')
plt.show()

# %% [markdown]
# По выходным объявления публикуются в 2 раза реже.

# %%
ax = data['month'].hist(bins=12, figsize=(10, 7))
ax.set_title('Распределение по дня месяцам')
ax.set_xlabel('месяц')
ax.set_ylabel('частота')
plt.show()

# %% [markdown]
# Мало публикаций в январе. С февраля по апрель - самый пик с плавным уменьшением. Затем идёт резкий спад в мае. Потом до ноября плавно количество публикаций растёт и падает в ноябре.

# %% [markdown]
# <div class="alert alert-da
#             nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Осталось добавить одну гистограмму
#
# Шаг 4. Проведите исследовательский анализ данных:
# 1.	Изучите следующие параметры объектов:
#     +	общая площадь;
#     +	жилая площадь;
#     +	площадь кухни;
#     +	цена объекта;
#     +	количество комнат;
#     +	высота потолков;
#     +	этаж квартиры;
#     +	тип этажа квартиры («первый», «последний», «другой»);
#     +	__общее количество этажей в доме;__
#     +	расстояние до центра города в метрах;
#     +	расстояние до ближайшего аэропорта;
#     +	расстояние до ближайшего парка;
#     +	день и месяц публикации объявления.
#
#
# __Постройте отдельные гистограммы для каждого из этих параметров.__ Опишите все ваши наблюдения по параметрам в ячейке с типом markdown.

# %% [markdown]
# #### Изучаем быстроту продаж квартир

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# стоит выделять разделы проекта заголовками разного уровня, за уровень отвечает количество знаков #
#
#         # example 1
#
#
#
#         #### example 2

# %%
ax = data['days_exposition'].hist(bins=1000, figsize=(10, 7))
ax.set_title('Распределение длительности продаж')
ax.set_xlabel('длительность продажи')
ax.set_ylabel('частота')
plt.show()

# %%
print(f'Среднее арифметическое: {data["days_exposition"].mean():.2f}')
print(f'Медиана: {data["days_exposition"].median():.2f}')
# Out:
# Среднее арифметическое: 168.40
# Медиана: 97.00

# %% [markdown]
# Всё, что до медианы, - быстрые продажи. Необычно долгими я бы назвал продажи превышающие 200 дней.

# %% [markdown]
# <div class="alert alert-dang
#             er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит пересчитать статистики скорости продажи после восстановления пропусков
#
# и обратить внимание на пики в первые сто дней и на изменение скорости продаж по годам

# %%
for year in sorted(data['year'].unique()):
    ax = data.query(f'year == {year}')['days_exposition'].hist()
    ax.set_title(f'Распределение длительности продаж в {year} году')
    ax.set_xlabel('длительность продажи')
    ax.set_ylabel('частота')
    plt.show()

# %% [markdown]
# #### Факторы больше всего влияющие на стоимость объекта

# %%
for feature in ['total_area', 'living_area', 'kitchen_area']:
    _ = data.plot(x=feature, y='last_price', kind='scatter', alpha=0.05)

# %%
print(f'Корреляция между стоимостью квартиры и общей площадью составила {data["last_price"].corr(data["total_area"]):.2f}')
print(f'Корреляция между стоимостью квартиры и жилой площадью составила {data["last_price"].corr(data["living_area"]):.2f}')
print(f'Корреляция между стоимостью квартиры и площадью кухни составила {data["last_price"].corr(data["kitchen_area"]):.2f}')
# Out:
# Корреляция между стоимостью квартиры и общей площадью составила 0.76
# Корреляция между стоимостью квартиры и жилой площадью составила 0.64
# Корреляция между стоимостью квартиры и площадью кухни составила 0.55

# %% [markdown]
# <div class="alert alert-info">
#     <font size="4", color="black">
#         <b>✍ Комментарий студента</b>
#     </font>
#     <br/>
#     <br/>
#     <font size="3", color="black">
#         не то, чтобы сильно лучше стало
#     </font>
# <div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />пример в бонусной части

# %%
_ = data.groupby('rooms')['last_price'].median().plot(kind='bar', rot=0)

# %%
_ = data.groupby('floor_type')['last_price'].median().plot(kind='bar', rot=0)

# %%
_ = data.groupby('weekday')['last_price'].median().plot(kind='bar', rot=0)

# %%
_ = data.groupby('month')['last_price'].median().plot(kind='bar', rot=0)

# %%
_ = data.groupby('year')['last_price'].median().plot(kind='bar', rot=0)

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Стоит добавить расчет коэффициента корреляции для линейных параметров и минивыводы по самому важному разделу проекта__
#
# Шаг 4. Проведите исследовательский анализ данных:
#
# 3.	Какие факторы больше всего влияют на общую (полную) стоимость объекта?
#     Изучите, зависит ли цена от:
#     +	общей площади;
#     +	жилой площади;
#     +	площади кухни;
#     +	количества комнат;
#     +	этажа, на котором расположена квартира (первый, последний, другой);
#     +	даты размещения (день недели, месяц, год).
#
# Постройте графики, которые покажут зависимость цены от указанных выше параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы.
#
#
#
# Советы по графикам:
#
# + __зависимость параметров (от площади, числа комнат, удалённости от центра) оптимальнее рассматривать на точечных графиках (тип scatter),__
# + динамику на линейных (это про сравнение цен за год, месяц, день недели),
# + сравнение цен на барах (для сравнение средней стоимости квартиры по трем категориям)

# %% [markdown]
# #### Цена за квадратный метр

# %%
meter_price = data.pivot_table(index='locality_name', values='meter_price', aggfunc=['count', 'mean'])
meter_price.columns=['count', 'mean']
meter_price.sort_values('count', ascending=False)[:10].sort_values('mean', ascending=False)
# Out:
#                    count           mean
# locality_name
# Санкт-Петербург    13516  108332.273438
# Пушкин               321  102303.250000
# посёлок Парголово    273   92803.390625
# деревня Кудрово      257   92755.101562
# посёлок Мурино       483   86231.601562
# посёлок Шушары       396   78726.765625
# Колпино              325   75194.031250
# Гатчина              286   68656.195312
# Всеволожск           365   67313.296875
# Выборг               189   58107.957031

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />ТОП-10 рассчитан корректно

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Недостаточно найти числа, стоит их показать красиво, удобно и наглядно, чтобы одного взгляда хватило, где самые самые, а где подешевле 📊

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Постер поможет выбирать вид графиков](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> на проектах стоит снижать размерность выводимой информации, где не требуется максимальная точность, до одного или двух знаков после запятой
#
#         Всеволожск	391	129265.859375
#         Гатчина	306	120912.539062
#         Выборг	233	99028.914062

# %% [markdown]
# #### Средние цены по удалённости от центра

# %%
_ = data.query('locality_name == "Санкт-Петербург"').groupby('cityCenters_km')['last_price'].mean().plot()

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Молодец, у тебя получилось сгруппировать и построить изменение средней цены в зависимости от расстояния от центра

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# ~~В данной лабораторной работе~~ Предобработали данные:
# - где могли заполнили пропуски, где не могли - оставили
# - обработали выбивающиеся значения: что-то поудаляли, что-то отредактировали
#
# Нашли следующие инсайты:
# - стоимость квартиры сильно коррелирует с жилой площадью
# - квартиры с бОльшим количеством комнат стоят больше (капитан очевидность)
# - с 2014 года количество предложений о продажах падали до 2017 года и чуть откатились к 2019
# - поразила история продаж с 2014 года (лучше смотреть на графики, сложно описать кратко)
#
# Сложно мне лить воду. Можно конкретные вопросы?

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Молодец, у тебя получилось очень многое, я понимаю

# %% [markdown]
# <div class="alert alert-da
#             nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Оформление вывода: стоит кратко напомнить цель исследования, как мы его провели, какие параметры рассматривали, какие редкие и выбивающиеся значения убрали, какие особенности и инсайты в данных нашли (упоминаем только основные 3-5,  с приведением найденных чисел), выделяем сильные корреляционные связи на парных признаках, если есть
#
#  + можно представить средние значения параметров,  которые были исследованы
#
# В окончательном выводе могут быть и такие предположения, что такой-то  и такой-то сегмент квартир стоит изучить в таком разрезе, своде и т.д., т.о. очертив себе план будущих исследований :)

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Выполнил исследовательскую работу, молодец, показал хороший уровень навыков программирования
#
# Критические ❌ комментарии
#
#
# + вернуть пропуски в колонку о скорости продаж
# + проверить корректность заполнения пропусков синтетическими данными
# + пересчитать скорость продаж
# + подправить и добавить графиков в п.4.1
# + в п. 4.3 добавить расчет коэф. корреляции
# + дополнить итоговый вывод цифрами и сравнениями
#
#
# С ними важно поработать и исправить
#
# Стоит обратить внимание и на такие комментарии ⚠️
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# <p> Доп. материал: методы группировки и расчета суммы, средних и т.д.
#
# [Подробное руководство по группировке и агрегированию с помощью pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%B4%D1%80%D0%BE%D0%B1%D0%BD%D0%BE%D0%B5%20%D1%80%D1%83%D0%BA%D0%BE%D0%B2%D0%BE%D0%B4%D1%81%D1%82%D0%B2%D0%BE%20%D0%BF%D0%BE%20%D0%B3%D1%80%D1%83%D0%BF%D0%BF%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B5%20%D0%B8%20%D0%B0%D0%B3%D1%80%D0%B5%D0%B3%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8E%20%D1%81%20%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D1%8C%D1%8E%20pandas.html)
#
#  Интересная функция в библиотеке пандаса
#
# [Понимание функции transform в Pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%BD%D0%B8%D0%BC%D0%B0%D0%BD%D0%B8%D0%B5%20%D1%84%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D0%B8%20transform%20%D0%B2%20Pandas.html)

# %% [markdown]
# ### Бонус

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />Диаграмма рассеяния

# %%
# check
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# check
sns.pairplot(data[['last_price', 'total_area', 'rooms', 'cityCenters_nearest']])
plt.gcf().set_size_inches(12, 12);

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [5.2. Scatter - график разброса (точки)](https://pyprog.pro/mpl/mpl_scatter.html?ysclid=l65k3vmmqd649359421)

# %%
# check
(
    data[data['rooms'] == 3]
    .query('total_area < 201 and last_price < 25_000_000')
    .plot(kind='scatter', y='last_price' , x='total_area', alpha=0.5, subplots=True, figsize=(15, 8), c='b', s=4)
)
plt.title('Диаграмма рассеяния — Общая площадь — цена трешки')


(
    data[data['rooms'] == 3]
    .query('total_area < 201 and last_price < 25_000_000')
    .plot(kind='scatter', y='last_price' , x='living_area', alpha=0.5, figsize=(15, 8), c='r', s=4)
)
plt.title('Диаграмма рассеяния — Жилая площадь — цена трешки')

(
    data[data['rooms'] == 3]
    .query('total_area < 201 and last_price < 25_000_000')
    .plot(kind='scatter', y='last_price' , x='kitchen_area', alpha=0.5, figsize=(15, 8), c='g', s=4)
)
plt.title('Диаграмма рассеяния — Жилая площадь — цена трешки')
# Out:
# E:\Projects\YandexPracticum\venv\lib\site-packages\pandas\plotting\_matplotlib\core.py:1254: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# Text(0.5, 1.0, 'Диаграмма рассеяния — Жилая площадь — цена трешки')

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />а эти искусственные значения в жилой площади возможно приведут к аномалиям

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [ ]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [ ]  определены пропущенные значения
# - [ ]  заполнены пропущенные значения там, где это возможно
# - [ ]  есть пояснение, какие пропущенные значения обнаружены
# - [ ]  изменены типы данных
# - [ ]  есть пояснение, в каких столбцах изменены типы и почему
# - [ ]  устранены неявные дубликаты в названиях населённых пунктов
# - [ ]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [ ]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [ ]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [ ]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [ ]  посчитано и добавлено в таблицу: год публикации объявления
# - [ ]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [ ]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [ ]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [ ]  построены гистограммы для каждого параметра
# - [ ]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [ ]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [ ]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [ ]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [ ]  в каждом этапе есть промежуточные выводы
# - [ ]  есть общий вывод
